# %%
pip install google-cloud-bigquery
# Out:
# Collecting google-cloud-bigquery
#   Downloading google_cloud_bigquery-3.35.1-py3-none-any.whl.metadata (8.0 kB)
# Collecting google-api-core<3.0.0,>=2.11.1 (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery)
#   Downloading google_api_core-2.25.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-auth<3.0.0,>=2.14.1 (from google-cloud-bigquery)
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting google-cloud-core<3.0.0,>=2.4.1 (from google-cloud-bigquery)
#   Downloading google_cloud_core-2.4.3-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media<3.0.0,>=2.0.0 (from google-cloud-bigquery)
#   Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: packaging>=24.2.0 in c:\users\vasavi kota\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-bigquery) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\vasavi kota\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in c:\users\vasavi kota\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-bigquery) (2.32.4)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery)
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery)
#   Downloading protobuf-6.31.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery)
#   Downloading proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery)
#   Downloading grpcio-1.74.0-cp310-cp310-win_amd64.whl.metadata (4.0 kB)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery)
#   Downloading grpcio_status-1.74.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery)
#   Downloading google_crc32c-1.7.1-cp310-cp310-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\vasavi kota\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vasavi kota\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vasavi kota\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vasavi kota\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vasavi kota\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2025.8.3)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading google_cloud_bigquery-3.35.1-py3-none-any.whl (256 kB)
# Downloading google_api_core-2.25.1-py3-none-any.whl (160 kB)
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading google_cloud_core-2.4.3-py2.py3-none-any.whl (29 kB)
# Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
# Downloading google_crc32c-1.7.1-cp310-cp310-win_amd64.whl (33 kB)
# Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Downloading grpcio-1.74.0-cp310-cp310-win_amd64.whl (4.5 MB)
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.5 MB 882.6 kB/s eta 0:00:05
#    ---- ----------------------------------- 0.5/4.5 MB 882.6 kB/s eta 0:00:05
#    ------ --------------------------------- 0.8/4.5 MB 860.9 kB/s eta 0:00:05
#    --------- ------------------------------ 1.0/4.5 MB 968.5 kB/s eta 0:00:04
#    ------------- -------------------------- 1.6/4.5 MB 1.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 1.8/4.5 MB 1.2 MB/s eta 0:00:03
#    ------------------ --------------------- 2.1/4.5 MB 1.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 2.6/4.5 MB 1.3 MB/s eta 0:00:02
#    --------------------------- ------------ 3.1/4.5 MB 1.4 MB/s eta 0:00:01
#    -------------------------------- ------- 3.7/4.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 4.2/4.5 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.5/4.5 MB 1.6 MB/s  0:00:02
# Downloading grpcio_status-1.74.0-py3-none-any.whl (14 kB)
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Downloading protobuf-6.31.1-cp310-abi3-win_amd64.whl (435 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Installing collected packages: pyasn1, protobuf, grpcio, google-crc32c, cachetools, rsa, pyasn1-modules, proto-plus, googleapis-common-protos, google-resumable-media, grpcio-status, google-auth, google-api-core, google-cloud-core, google-cloud-bigquery
#
#    ----------------------------------------  0/15 [pyasn1]
#    ----------------------------------------  0/15 [pyasn1]
#    ----------------------------------------  0/15 [pyasn1]
#    ----------------------------------------  0/15 [pyasn1]
#    -- -------------------------------------  1/15 [protobuf]
#    -- -------------------------------------  1/15 [protobuf]
#    -- -------------------------------------  1/15 [protobuf]
#    -- -------------------------------------  1/15 [protobuf]
#    -- -------------------------------------  1/15 [protobuf]
#    -- -------------------------------------  1/15 [protobuf]
#    -- -------------------------------------  1/15 [protobuf]
#    -- -------------------------------------  1/15 [protobuf]
#    -- -------------------------------------  1/15 [protobuf]
#    -- -------------------------------------  1/15 [protobuf]
#    -- -------------------------------------  1/15 [protobuf]
#    ----- ----------------------------------  2/15 [grpcio]
#    ----- ----------------------------------  2/15 [grpcio]
#    ----- ----------------------------------  2/15 [grpcio]
#    ----- ----------------------------------  2/15 [grpcio]
#    ----- ----------------------------------  2/15 [grpcio]
#    ----- ----------------------------------  2/15 [grpcio]
#    ----- ----------------------------------  2/15 [grpcio]
#    ----- ----------------------------------  2/15 [grpcio]
#    -------- -------------------------------  3/15 [google-crc32c]
#    ---------- -----------------------------  4/15 [cachetools]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ------------------ ---------------------  7/15 [proto-plus]
#    ------------------ ---------------------  7/15 [proto-plus]
#    ------------------ ---------------------  7/15 [proto-plus]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    ------------------------ ---------------  9/15 [google-resumable-media]
#    ------------------------ ---------------  9/15 [google-resumable-media]
#    ------------------------ ---------------  9/15 [google-resumable-media]
#    -------------------------- ------------- 10/15 [grpcio-status]
#    ----------------------------- ---------- 11/15 [google-auth]
#    ----------------------------- ---------- 11/15 [google-auth]
#    ----------------------------- ---------- 11/15 [google-auth]
#    ----------------------------- ---------- 11/15 [google-auth]
#    ----------------------------- ---------- 11/15 [google-auth]
#    ----------------------------- ---------- 11/15 [google-auth]
#    ----------------------------- ---------- 11/15 [google-auth]
#    ----------------------------- ---------- 11/15 [google-auth]
#    ----------------------------- ---------- 11/15 [google-auth]
#    ----------------------------- ---------- 11/15 [google-auth]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    ---------------------------------- ----- 13/15 [google-cloud-core]
#    ------------------------------------- -- 14/15 [google-cloud-bigquery]
#    ------------------------------------- -- 14/15 [google-cloud-bigquery]
#    ------------------------------------- -- 14/15 [google-cloud-bigquery]
#    ------------------------------------- -- 14/15 [google-cloud-bigquery]
#    ------------------------------------- -- 14/15 [google-cloud-bigquery]
#    ------------------------------------- -- 14/15 [google-cloud-bigquery]
#    ------------------------------------- -- 14/15 [google-cloud-bigquery]
#    ------------------------------------- -- 14/15 [google-cloud-bigquery]
#    ---------------------------------------- 15/15 [google-cloud-bigquery]
#
# Successfully installed cachetools-5.5.2 google-api-core-2.25.1 google-auth-2.40.3 google-cloud-bigquery-3.35.1 google-cloud-core-2.4.3 google-crc32c-1.7.1 google-resumable-media-2.7.2 googleapis-common-protos-1.70.0 grpcio-1.74.0 grpcio-status-1.74.0 proto-plus-1.26.1 protobuf-6.31.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 rsa-4.9.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, to_date
# 1. Create SparkSession
spark = SparkSession.builder.appName("EcommerceDataset").getOrCreate()

# 2. Load the CSV file with header and schema inference


df = spark.read.csv("C:/Users/Vasavi kota/Downloads/Ecommerce.csv",header=True,inferSchema=True)

# 3. Show first few rows of data
df.show()

# 4. Print schema of the DataFrame
df.printSchema()
df = df.dropna(subset=["Product", "Order_Date"])

# Fill missing values in less important columns
df = df.fillna({
    "Customer_Id": "Unknown",
    "Quantity": 0,
    "Sales": 0.0,
    "Profit": 0.0,
    "Discount": 0.0,
    "Shipping_Cost": 0.0
})

# Standardize string columns to lowercase
for col_name in ["Gender", "Device_Type", "Customer_Login_type", "Product_Category", "Product", "Order_Priority", "Payment_method"]:
    df = df.withColumn(col_name, col(col_name).cast("string"))

# Remove duplicate rows if any
df = df.dropDuplicates()


#
# 11. Final check: Show cleaned data and schema
df.show(truncate=False)
df.printSchema()
# Cache the data in memory
df.cache()

# Or persist with MEMORY_AND_DISK (safer for larger data)
from pyspark.storagelevel import StorageLevel
df.persist(StorageLevel.MEMORY_AND_DISK)

# Force action to trigger caching
df.count()

# Check if it's cached
print("Cached:", df.storageLevel.useMemory)

# Unpersist when done (optional)
df.unpersist()
print("Unpersisted:", df.storageLevel.useMemory)

df.write.mode("overwrite").csv("C:/Users/Vasavi kota/Downloads/Ecommerce.csv",header=True )
# Out:
# +----------+-------------------+-----+-----------+------+-----------+-------------------+------------------+--------------------+-----+--------+--------+------+-------------+--------------+--------------+
# |Order_Date|               Time|Aging|Customer_Id|Gender|Device_Type|Customer_Login_type|  Product_Category|             Product|Sales|Quantity|Discount|Profit|Shipping_Cost|Order_Priority|Payment_method|
# +----------+-------------------+-----+-----------+------+-----------+-------------------+------------------+--------------------+-----+--------+--------+------+-------------+--------------+--------------+
# |2018-01-02|2025-08-11 10:56:33|  8.0|      37077|Female|        Web|             Member|Auto & Accessories|   Car Media Players|140.0|     1.0|     0.3|  46.0|          4.6|        Medium|   credit_card|
# |2018-07-24|2025-08-11 20:41:37|  2.0|      59173|Female|        Web|             Member|Auto & Accessories|        Car Speakers|211.0|     1.0|     0.3| 112.0|         11.2|        Medium|   credit_card|
# |2018-11-08|2025-08-11 08:38:49|  8.0|      41066|Female|        Web|             Member|Auto & Accessories|     Car Body Covers|117.0|     5.0|     0.1|  31.2|          3.1|      Critical|   credit_card|
# |2018-04-18|2025-08-11 19:28:06|  7.0|      50741|Female|        Web|             Member|Auto & Accessories|     Car & Bike Care|118.0|     1.0|     0.3|  26.2|          2.6|          High|   credit_card|
# |2018-08-13|2025-08-11 21:18:39|  9.0|      53639|Female|        Web|             Member|Auto & Accessories|                Tyre|250.0|     1.0|     0.3| 160.0|         16.0|      Critical|   credit_card|
# |2018-07-09|2025-08-11 21:57:05|  8.0|      39783|Female|        Web|             Member|Auto & Accessories|          Bike Tyres| 72.0|     1.0|     0.3|  24.0|          2.4|      Critical|   credit_card|
# |2018-05-16|2025-08-11 13:10:30|  1.0|      26767|Female|        Web|             Member|Auto & Accessories|             Car Mat| 54.0|     1.0|     0.3|  54.0|          5.4|          High|   credit_card|
# |2018-06-23|2025-08-11 18:29:09|  7.0|      20719|Female|        Web|             Member|Auto & Accessories|     Car Seat Covers|114.0|     5.0|     0.2|  22.6|          2.3|      Critical|   credit_card|
# |2018-07-29|2025-08-11 11:55:02|  7.0|      46947|Female|        Web|             Member|Auto & Accessories|Car Pillow & Neck...|231.0|     5.0|     0.3| 116.4|         11.6|      Critical|   credit_card|
# |2018-05-16|2025-08-11 19:41:10| 10.0|      31839|Female|        Web|             Member|Auto & Accessories|   Car Media Players|140.0|     1.0|     0.2|  54.4|          5.4|      Critical|   money_order|
# |2018-07-13|2025-08-11 19:58:11| 10.0|      22249|Female|        Web|             Member|Auto & Accessories|        Car Speakers|211.0|     4.0|     0.1| 122.6|         12.3|      Critical|   credit_card|
# |2018-10-07|2025-08-11 10:06:19|  1.0|      15109|Female|        Web|             Member|Auto & Accessories|     Car Body Covers|117.0|     4.0|     0.3|  18.3|          1.8|          High|   credit_card|
# |2018-07-25|2025-08-11 17:44:10|  7.0|      18622|Female|        Web|             Member|Auto & Accessories|     Car & Bike Care|118.0|     1.0|     0.2|  35.6|          3.6|      Critical|   credit_card|
# |2018-12-01|2025-08-11 14:14:28|  5.0|      56296|Female|        Web|             Member|Auto & Accessories|                Tyre|250.0|     1.0|     0.3| 140.0|         14.0|          High|   credit_card|
# |2018-10-07|2025-08-11 19:03:12|  9.0|      34138|Female|        Web|             Member|Auto & Accessories|          Bike Tyres| 72.0|     4.0|     0.1|  18.0|          1.8|        Medium|   credit_card|
# |2018-06-02|2025-08-11 19:00:43| 10.0|      51112|Female|        Web|             Member|Auto & Accessories|             Car Mat| 54.0|     1.0|     0.1|  27.0|          2.7|      Critical|   credit_card|
# |2018-03-26|2025-08-11 23:41:31|  4.0|      57057|Female|        Web|             Member|Auto & Accessories|     Car Seat Covers|114.0|     1.0|     0.3|  22.6|          2.3|          High|   credit_card|
# |2018-04-21|2025-08-11 00:03:41|  7.0|      50942|Female|        Web|             Member|Auto & Accessories|Car Pillow & Neck...|231.0|     5.0|     0.3|  93.3|          9.3|          High|   credit_card|
# |2018-01-26|2025-08-11 15:54:26|  7.0|      42384|Female|        Web|             Member|Auto & Accessories|   Car Media Players|140.0|     1.0|     0.3|  46.0|          4.6|      Critical|   credit_card|
# |2018-02-18|2025-08-11 14:31:30|  6.0|      26127|Female|        Web|             Member|Auto & Accessories|        Car Speakers|211.0|     1.0|     0.2| 122.6|         12.3|      Critical|   credit_card|
# +----------+-------------------+-----+-----------+------+-----------+-------------------+------------------+--------------------+-----+--------+--------+------+-------------+--------------+--------------+
# only showing top 20 rows
# root
#  |-- Order_Date: date (nullable = true)
#  |-- Time: timestamp (nullable = true)
#  |-- Aging: double (nullable = true)
#  |-- Customer_Id: integer (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Device_Type: string (nullable = true)
#  |-- Customer_Login_type: string (nullable = true)
#  |-- Product_Category: string (nullable = true)
#  |-- Product: string (nullable = true)
#  |-- Sales: double (nullable = true)
#  |-- Quantity: double (nullable = true)
#  |-- Discount: double (nullable = true)
#  |-- Profit: double (nullable = true)
#  |-- Shipping_Cost: double (nullable = true)
#  |-- Order_Priority: string (nullable = true)
#  |-- Payment_method: string (nullable = true)
#
# +----------+-------------------+-----+-----------+------+-----------+-------------------+------------------+----------------------+-----+--------+--------+------+-------------+--------------+--------------+
# |Order_Date|Time               |Aging|Customer_Id|Gender|Device_Type|Customer_Login_type|Product_Category  |Product               |Sales|Quantity|Discount|Profit|Shipping_Cost|Order_Priority|Payment_method|
# +----------+-------------------+-----+-----------+------+-----------+-------------------+------------------+----------------------+-----+--------+--------+------+-------------+--------------+--------------+
# |2018-02-05|2025-08-11 18:24:22|7.0  |54432      |Male  |Web        |Member             |Auto & Accessories|Bike Tyres            |72.0 |5.0     |0.2     |14.4  |1.4          |Medium        |credit_card   |
# |2018-04-26|2025-08-11 13:24:33|5.0  |14052      |Male  |Web        |Member             |Auto & Accessories|Bike Tyres            |72.0 |1.0     |0.2     |72.0  |7.2          |High          |credit_card   |
# |2018-06-11|2025-08-11 20:04:57|4.0  |46001      |Male  |Web        |Member             |Auto & Accessories|Car Speakers          |211.0|5.0     |0.3     |78.3  |7.8          |Medium        |money_order   |
# |2018-09-06|2025-08-11 13:45:15|10.0 |18452      |Male  |Web        |Member             |Auto & Accessories|Car Speakers          |211.0|1.0     |0.1     |128.9 |12.9         |High          |credit_card   |
# |2018-03-09|2025-08-11 09:29:19|2.0  |42127      |Male  |Web        |Member             |Auto & Accessories|Car Speakers          |211.0|1.0     |0.3     |118.3 |11.8         |Medium        |credit_card   |
# |2018-10-11|2025-08-11 16:02:43|9.0  |33337      |Male  |Web        |Member             |Auto & Accessories|Car Pillow & Neck Rest|231.0|1.0     |0.3     |130.2 |13.0         |Critical      |e_wallet      |
# |2018-05-02|2025-08-11 13:10:07|10.0 |53870      |Male  |Web        |Member             |Auto & Accessories|Bike Tyres            |72.0 |1.0     |0.1     |36.0  |3.6          |High          |e_wallet      |
# |2018-10-17|2025-08-11 20:16:55|4.0  |59040      |Male  |Web        |Member             |Auto & Accessories|Car Body Covers       |117.0|1.0     |0.1     |35.8  |3.6          |Critical      |credit_card   |
# |2018-03-26|2025-08-11 15:02:43|1.0  |51042      |Male  |Web        |Member             |Auto & Accessories|Tyre                  |250.0|5.0     |0.3     |120.0 |12.0         |High          |e_wallet      |
# |2018-07-07|2025-08-11 20:04:55|1.0  |50084      |Male  |Web        |Member             |Auto & Accessories|Car Seat Covers       |114.0|1.0     |0.1     |31.7  |3.2          |Critical      |credit_card   |
# |2018-05-01|2025-08-11 18:42:40|2.0  |32815      |Male  |Web        |Member             |Auto & Accessories|Car Media Players     |140.0|1.0     |0.3     |46.0  |4.6          |Medium        |credit_card   |
# |2018-06-11|2025-08-11 08:30:28|9.0  |12406      |Male  |Web        |Member             |Auto & Accessories|Car Speakers          |211.0|1.0     |0.1     |124.7 |12.5         |High          |credit_card   |
# |2018-03-10|2025-08-11 23:02:03|4.0  |32095      |Male  |Web        |Member             |Auto & Accessories|Car Pillow & Neck Rest|231.0|1.0     |0.1     |148.7 |14.9         |High          |credit_card   |
# |2018-03-06|2025-08-11 22:54:33|1.0  |13641      |Female|Web        |Member             |Auto & Accessories|Car Media Players     |140.0|1.0     |0.1     |58.6  |5.9          |High          |credit_card   |
# |2018-05-27|2025-08-11 00:55:16|3.0  |52377      |Male  |Web        |Member             |Auto & Accessories|Car & Bike Care       |118.0|1.0     |0.3     |26.2  |2.6          |High          |e_wallet      |
# |2018-10-03|2025-08-11 10:28:43|6.0  |40448      |Female|Web        |Member             |Auto & Accessories|Car Mat               |54.0 |5.0     |0.2     |10.8  |1.1          |Medium        |credit_card   |
# |2018-10-25|2025-08-11 21:13:29|5.0  |37300      |Male  |Web        |Member             |Auto & Accessories|Car Speakers          |211.0|1.0     |0.2     |122.6 |12.3         |High          |credit_card   |
# |2018-09-13|2025-08-11 13:19:27|5.0  |38574      |Male  |Web        |Member             |Auto & Accessories|Bike Tyres            |72.0 |1.0     |0.3     |36.0  |3.6          |Medium        |money_order   |
# |2018-07-15|2025-08-11 12:57:04|8.0  |42205      |Male  |Web        |Member             |Auto & Accessories|Bike Tyres            |72.0 |4.0     |0.3     |18.0  |1.8          |Medium        |credit_card   |
# |2018-10-27|2025-08-11 11:16:44|2.0  |34570      |Male  |Web        |Member             |Auto & Accessories|Car & Bike Care       |118.0|5.0     |0.3     |8.5   |0.9          |High          |money_order   |
# +----------+-------------------+-----+-----------+------+-----------+-------------------+------------------+----------------------+-----+--------+--------+------+-------------+--------------+--------------+
# only showing top 20 rows
# root
#  |-- Order_Date: date (nullable = true)
#  |-- Time: timestamp (nullable = true)
#  |-- Aging: double (nullable = true)
#  |-- Customer_Id: integer (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Device_Type: string (nullable = true)
#  |-- Customer_Login_type: string (nullable = true)
#  |-- Product_Category: string (nullable = true)
#  |-- Product: string (nullable = true)
#  |-- Sales: double (nullable = false)
#  |-- Quantity: double (nullable = false)
#  |-- Discount: double (nullable = false)
#  |-- Profit: double (nullable = false)
#  |-- Shipping_Cost: double (nullable = false)
#  |-- Order_Priority: string (nullable = true)
#  |-- Payment_method: string (nullable = true)
#
# Cached: True
# Unpersisted: False

# %%
from google.cloud import bigquery
import pandas as pd

# %%
import os
from google.cloud import bigquery

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:/Users/Vasavi kota/Downloads/calcium-aria-468209-b4-e99031666590.json"

client = bigquery.Client()

project_id = "calcium-aria-468209-b4"
dataset_id = "Ecommerce"
table_id = "E-commerce"
csv_file_path = "C:/Users/Vasavi kota/Downloads/Ecommerce.csv"

table_ref = f"{project_id}.{dataset_id}.{table_id}"

job_config = bigquery.LoadJobConfig(
    source_format=bigquery.SourceFormat.CSV,
    skip_leading_rows=1,      
    autodetect=True,           
    write_disposition="WRITE_TRUNCATE")

with open("C:/Users/Vasavi kota/Downloads/Ecommerce.csv", "rb") as source_file:
    load_job = client.load_table_from_file(
        source_file,
        destination=table_ref,
        job_config=job_config,
    )

load_job.result()

destination_table = client.get_table(table_ref)
print(f"Loaded {destination_table.num_rows} rows into {table_ref}.")
# Out:
# Loaded 51290 rows into calcium-aria-468209-b4.Ecommerce.E-commerce.
